# %% [markdown]
# # Finetunning do XGBoost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

import scipy.stats as stats

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score

from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
training_dataset = "data/raw/loan_data_large.csv"
test_dataset = "data/raw/loan_data_test.csv"

# %%
df = pd.read_csv(training_dataset)

# %%
pd.options.display.max_columns = None
df.loc[df['RiskScore'] == 82.0]
# Out:
#            ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 21234  2076-02-20 00:00:00   52         59482          498    Self-Employed
# 58743  2178-11-01 00:00:00   29         19310          571         Employed
#
#       EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  \
# 21234       Bachelor          27       55615            60        Single
# 58743    High School           5       24426            60       Married
#
#        NumberOfDependents HomeOwnershipStatus  MonthlyDebtPayments  \
# 21234                   0            Mortgage                  426
# 58743                   3                Rent                  420
#
#        CreditCardUtilizationRate  NumberOfOpenCreditLines  \
# 21234                   0.518088                        0
# 58743                   0.382693                        3
#
#        NumberOfCreditInquiries  DebtToIncomeRatio  BankruptcyHistory  \
# 21234                        1           0.540737                  1
# 58743                        1           0.637400                  1
#
#       LoanPurpose  PreviousLoanDefaults  PaymentHistory  \
# 21234        Home                     1              24
# 58743        Home                     1              29
#
#        LengthOfCreditHistory  SavingsAccountBalance  CheckingAccountBalance  \
# 21234                      5                    827                    9340
# 58743                      1                   2999                     461
#
#        TotalAssets  TotalLiabilities  MonthlyIncome  \
# 21234        75638             73726    4956.833333
# 58743        12115             24546    1609.166667
#
#        UtilityBillsPaymentHistory  JobTenure  NetWorth  BaseInterestRate  \
# 21234                    0.904017          5      1912          0.311615
# 58743                    0.747331          6      4658          0.243926
#
#        InterestRate  MonthlyLoanPayment  TotalDebtToIncomeRatio  LoanApproved  \
# 21234      0.285198         1749.099325                0.438808             0
# 58743      0.220153          674.832146                0.680372             0
#
#        RiskScore
# 21234       82.0
# 58743       82.0

# %%
df.shape
# Out:
# (100000, 36)

# %%
def clean_dataset(dataset, features_to_remove):
    dataset = dataset.drop(columns=features_to_remove)
    dataset = dataset.dropna()
    dataset['EducationLevel'] = dataset['EducationLevel'].astype('category').cat.codes
    dataset['EmploymentStatus'] = dataset['EmploymentStatus'].astype('category').cat.codes
    dataset['HomeOwnershipStatus'] = dataset['HomeOwnershipStatus'].astype('category').cat.codes
    return dataset

# %%
columns_to_remove = ['ApplicationDate', 'LoanPurpose', 'MaritalStatus', 'LoanApproved', 'CreditCardUtilizationRate']
df = clean_dataset(df, columns_to_remove)
# Out:
# 19

# %%
df['JobTenure'].unique()
# Out:
# array([ 7,  8,  6,  4,  5,  1,  3,  9,  2, 10, 12,  0, 11, 13, 15, 17, 14,
#        16, 22])

# %%
X = df.drop(columns=['RiskScore'], axis=1)
y = df['RiskScore']

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# # Otimizando o modelo

# %%
xgboost_model = XGBRegressor()

# %%
# número de folds
k = 5
mape_scores = []
kf = KFold(n_splits=k, shuffle=True, random_state=42)

for train_index, val_index in kf.split(X):
  x_train, x_val = X[train_index], X[val_index]
  y_train, y_val = y[train_index], y[val_index]

  xgboost_model.fit(x_train, y_train)
  y_pred = xgboost_model.predict(x_val)

  mape = mean_absolute_percentage_error(y_val, y_pred)
  mape_scores.append(mape)

# %%
mape_scores
# Out:
# [0.03410368425942694,
#  0.034466199832982235,
#  0.03499306452660847,
#  0.03436880971112577,
#  0.03448691258773315]

# %% [markdown]
# Os valores estão muito próximos para cada fold, o que é um bom sinal. Vamos calcular a média:

# %%
mape_mean = np.mean(mape_scores)
print(f'MAPE médio: {mape_mean}')
# Out:
# MAPE médio: 0.03448373418357532

# %% [markdown]
# ### Separando 10% para o teste final

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
xgboost_model = XGBRegressor()

# %%
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)
mape_scores = []

for train_index, val_index in kf.split(X_train, y_train):
  x_train, x_val = X[train_index], X[val_index]
  y_train, y_val = y[train_index], y[val_index]

  xgboost_model.fit(x_train, y_train)
  y_pred = xgboost_model.predict(x_val)

  mape = mean_absolute_percentage_error(y_val, y_pred)
  mape_scores.append(mape)

# %%
print(mape_scores)
mape_mean = np.mean(mape_scores)
print(f'MAPE médio: {mape_mean}')
# Out:
# [0.03476204375292032, 0.03458391978204043, 0.03484683194015244, 0.03468081104802604, 0.034442971482559315]
# MAPE médio: 0.03466331560113971

# %%
y_pred_2 = xgboost_model.predict(X_test)

# %%
mape_test = mean_absolute_percentage_error(y_test, y_pred_2)
mape_test
# Out:
# 0.02905169010368337

# %%
def evaluate_real_data(model):
  df_test = pd.read_csv(test_dataset)
  df_test = clean_dataset(df_test, columns_to_remove)
  X = df_test.drop(columns=['RiskScore'])
  y = df_test['RiskScore']

  X = scaler.transform(X)

  _, X_test, _, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
  y_pred = xgboost_model.predict(X_test)

  mse = mean_squared_error(y_test, y_pred, squared=True)
  rmse = np.sqrt(mse)
  mae = mean_absolute_error(y_test, y_pred)
  mape = mean_absolute_percentage_error(y_test, y_pred)
  r2 = r2_score(y_test, y_pred)
  print(f'MSE: {mse}\nRMSE: {rmse}\nMAE: {mae}\nMAPE: {mape}\nR2 Score: {r2}')

# %%
evaluate_real_data(xgboost_model)
# Out:
# MSE: 5.525745966072004
# RMSE: 2.3506905296257106
# MAE: 1.6182307867262096
# MAPE: 0.03398557930384665
# R2 Score: 0.9070434276594164
# /opt/homebrew/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# # Ajuste de hiperparâmetros

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ## GridSearch

# %%
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.1, 0.01, 0.001],
    'subsample': [0.5, 0.7, 1]
}

# %%
# Create the XGBoost model object
xgboost = XGBRegressor()

# %%
# Create the GridSearchCV object
grid_search = GridSearchCV(xgboost, param_grid)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bin=None,
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'learning_rate': [0.1, 0.01, 0.001],
#                          'max_depth': [3, 5, 7], 'subsample': [0.5, 0.7, 1]})

# %%
df_results = pd.DataFrame(grid_search.cv_results_)
df_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.208002      0.024082         0.003227        0.000597
# 1        0.213776      0.030264         0.003766        0.000425
# 2        0.216500      0.024947         0.003819        0.001137
# 3        0.293513      0.021668         0.006820        0.005159
# 4        0.270904      0.018367         0.004094        0.000480
# 5        0.261319      0.010522         0.004318        0.000378
# 6        0.413592      0.007335         0.005992        0.000222
# 7        0.431431      0.009416         0.005652        0.000224
# 8        0.442722      0.038303         0.006357        0.000692
# 9        0.193832      0.016738         0.003226        0.000746
# 10       0.173253      0.006517         0.002586        0.000139
# 11       0.165987      0.002955         0.002745        0.000196
# 12       0.258228      0.008448         0.003858        0.000250
# 13       0.258272      0.005428         0.004288        0.000522
# 14       0.267066      0.020017         0.004194        0.000189
# 15       0.492409      0.035971         0.006053        0.000464
# 16       0.473860      0.013234         0.007032        0.000487
# 17       0.431866      0.007998         0.006195        0.000161
# 18       0.177347      0.007035         0.002821        0.000401
# 19       0.172969      0.009975         0.002617        0.000113
# 20       0.179319      0.018777         0.003384        0.000442
# 21       0.249917      0.005406         0.004052        0.000188
# 22       0.247634      0.006807         0.003771        0.000237
# 23       0.241192      0.002978         0.004024        0.000364
# 24       0.459243      0.021496         0.007167        0.001745
# 25       0.446522      0.022204         0.006207        0.000153
# 26       0.430918      0.009012         0.006080        0.000235
#
#    param_learning_rate param_max_depth param_subsample  \
# 0                  0.1               3             0.5
# 1                  0.1               3             0.7
# 2                  0.1               3               1
# 3                  0.1               5             0.5
# 4                  0.1               5             0.7
# 5                  0.1               5               1
# 6                  0.1               7             0.5
# 7                  0.1               7             0.7
# 8                  0.1               7               1
# 9                 0.01               3             0.5
# 10                0.01               3             0.7
# 11                0.01               3               1
# 12                0.01               5             0.5
# 13                0.01               5             0.7
# 14                0.01               5               1
# 15                0.01               7             0.5
# 16                0.01               7             0.7
# 17                0.01               7               1
# 18               0.001               3             0.5
# 19               0.001               3             0.7
# 20               0.001               3               1
# 21               0.001               5             0.5
# 22               0.001               5             0.7
# 23               0.001               5               1
# 24               0.001               7             0.5
# 25               0.001               7             0.7
# 26               0.001               7               1
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'subsam...           0.881482
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'subsam...           0.881657
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'subsam...           0.880983
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'subsam...           0.903015
# 4   {'learning_rate': 0.1, 'max_depth': 5, 'subsam...           0.901853
# 5   {'learning_rate': 0.1, 'max_depth': 5, 'subsam...           0.901712
# 6   {'learning_rate': 0.1, 'max_depth': 7, 'subsam...           0.909621
# 7   {'learning_rate': 0.1, 'max_depth': 7, 'subsam...           0.909689
# 8   {'learning_rate': 0.1, 'max_depth': 7, 'subsam...           0.908267
# 9   {'learning_rate': 0.01, 'max_depth': 3, 'subsa...           0.470845
# 10  {'learning_rate': 0.01, 'max_depth': 3, 'subsa...           0.470011
# 11  {'learning_rate': 0.01, 'max_depth': 3, 'subsa...           0.469120
# 12  {'learning_rate': 0.01, 'max_depth': 5, 'subsa...           0.600847
# 13  {'learning_rate': 0.01, 'max_depth': 5, 'subsa...           0.600316
# 14  {'learning_rate': 0.01, 'max_depth': 5, 'subsa...           0.599473
# 15  {'learning_rate': 0.01, 'max_depth': 7, 'subsa...           0.678064
# 16  {'learning_rate': 0.01, 'max_depth': 7, 'subsa...           0.677900
# 17  {'learning_rate': 0.01, 'max_depth': 7, 'subsa...           0.677690
# 18  {'learning_rate': 0.001, 'max_depth': 3, 'subs...           0.080520
# 19  {'learning_rate': 0.001, 'max_depth': 3, 'subs...           0.080505
# 20  {'learning_rate': 0.001, 'max_depth': 3, 'subs...           0.080458
# 21  {'learning_rate': 0.001, 'max_depth': 5, 'subs...           0.109725
# 22  {'learning_rate': 0.001, 'max_depth': 5, 'subs...           0.109731
# 23  {'learning_rate': 0.001, 'max_depth': 5, 'subs...           0.109718
# 24  {'learning_rate': 0.001, 'max_depth': 7, 'subs...           0.129690
# 25  {'learning_rate': 0.001, 'max_depth': 7, 'subs...           0.129903
# 26  {'learning_rate': 0.001, 'max_depth': 7, 'subs...           0.129935
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.877443           0.876749           0.881352
# 1            0.878325           0.874499           0.881489
# 2            0.876708           0.875156           0.879506
# 3            0.899024           0.898123           0.902564
# 4            0.897485           0.897456           0.900949
# 5            0.897555           0.896932           0.901433
# 6            0.906684           0.906478           0.909767
# 7            0.907052           0.907438           0.909823
# 8            0.906597           0.905988           0.909741
# 9            0.470607           0.463832           0.469873
# 10           0.469592           0.463239           0.469388
# 11           0.468758           0.461908           0.468250
# 12           0.600328           0.593315           0.599975
# 13           0.599527           0.592403           0.599092
# 14           0.598601           0.591860           0.597978
# 15           0.676445           0.671539           0.675861
# 16           0.675847           0.671229           0.675427
# 17           0.675217           0.670695           0.674767
# 18           0.079970           0.077983           0.078811
# 19           0.079931           0.077928           0.078821
# 20           0.079849           0.077819           0.078800
# 21           0.109751           0.107634           0.108674
# 22           0.109695           0.107542           0.108658
# 23           0.109557           0.107532           0.108593
# 24           0.129244           0.127973           0.128536
# 25           0.129317           0.128087           0.128496
# 26           0.129222           0.128322           0.128334
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.878235         0.879052        0.001988                8
# 1            0.879541         0.879102        0.002616                7
# 2            0.877938         0.878058        0.002045                9
# 3            0.901384         0.900822        0.001933                4
# 4            0.900232         0.899595        0.001809                5
# 5            0.900012         0.899529        0.001963                6
# 6            0.908980         0.908306        0.001434                2
# 7            0.909361         0.908673        0.001182                1
# 8            0.908200         0.907758        0.001332                3
# 9            0.463457         0.467723        0.003348               16
# 10           0.462858         0.467018        0.003249               17
# 11           0.462215         0.466050        0.003270               18
# 12           0.596122         0.598118        0.002927               13
# 13           0.594976         0.597263        0.003054               14
# 14           0.593970         0.596377        0.002943               15
# 15           0.674462         0.675274        0.002196               10
# 16           0.674100         0.674900        0.002204               11
# 17           0.673360         0.674346        0.002299               12
# 18           0.078740         0.079205        0.000914               25
# 19           0.078649         0.079167        0.000927               26
# 20           0.078541         0.079093        0.000943               27
# 21           0.108698         0.108896        0.000787               22
# 22           0.108593         0.108844        0.000813               23
# 23           0.108522         0.108784        0.000793               24
# 24           0.128365         0.128762        0.000620               21
# 25           0.128477         0.128856        0.000659               19
# 26           0.128316         0.128826        0.000655               20

# %%
df_results.query('rank_test_score == 1')['params']
# Out:
# 7    {'learning_rate': 0.1, 'max_depth': 7, 'subsam...
# Name: params, dtype: object

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 7, 'subsample': 0.7}

# %% [markdown]
# ## RandomSearch

# %%
param_dist = {
    'max_depth': stats.randint(3, 10),
    'learning_rate': stats.uniform(0.01, 0.1),
    'subsample': stats.uniform(0.5, 0.5),
    'n_estimators':stats.randint(50, 200)
}

# %%
random_search = RandomizedSearchCV(xgboost, param_dist, random_state=42)

# %%
random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=None,...
#                    param_distributions={'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x32f542a20>,
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x33569f5f0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x3356b1ee0>,
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x3356b0bc0>},
#                    random_state=42)

# %%
# Print the best set of hyperparameters and the corresponding score
print("Best set of hyperparameters: ", random_search.best_params_)
print("Best score: ", random_search.best_score_)
# Out:
# Best set of hyperparameters:  {'learning_rate': 0.06986584841970366, 'max_depth': 9, 'n_estimators': 171, 'subsample': 0.5779972601681014}
# Best score:  0.9132259452581447

# %% [markdown]
# ## Validação cruzada com 10 folds

# %%
random_search = RandomizedSearchCV(xgboost, param_dist, cv=10, random_state=42)
random_search.fit(X_train, y_train)

print("Best set of hyperparameters: ", random_search.best_params_)
print("Best score: ", random_search.best_score_)
# Out:
# Best set of hyperparameters:  {'learning_rate': 0.06986584841970366, 'max_depth': 9, 'n_estimators': 171, 'subsample': 0.5779972601681014}
# Best score:  0.9142250870765996
