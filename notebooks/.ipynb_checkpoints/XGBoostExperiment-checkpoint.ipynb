# %% [markdown]
# # Finetunning do XGBoost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score

from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
training_dataset = "data/raw/loan_data_large.csv"
test_dataset = "data/raw/loan_data_test.csv"

# %%
df = pd.read_csv(training_dataset)

# %%
df.head()
# Out:
#        ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0  2018-01-01 00:00:00   61         40100          607         Employed
# 1  2018-01-02 00:00:00   45        196328          662         Employed
# 2  2018-01-03 00:00:00   41         69929          500         Employed
# 3  2018-01-04 00:00:00   18        178352          576         Employed
# 4  2018-01-05 00:00:00   36         69982          588    Self-Employed
#
#   EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  ...  \
# 0    High School          39       15442            24       Widowed  ...
# 1         Master          21       18447           108       Widowed  ...
# 2         Master          14       55248            24      Divorced  ...
# 3      Doctorate           0       23964            60        Single  ...
# 4      Associate           9       15280            36        Single  ...
#
#    MonthlyIncome UtilityBillsPaymentHistory  JobTenure  NetWorth  \
# 0    3341.666667                   0.895582          7      3561
# 1   16360.666667                   0.828974          8      8735
# 2    5827.416667                   0.883624          6      6961
# 3    7870.833333                   0.923136          4    580260
# 4    5831.833333                   0.847818          6     70933
#
#    BaseInterestRate  InterestRate  MonthlyLoanPayment  TotalDebtToIncomeRatio  \
# 0          0.186942      0.214766          797.117108                0.375895
# 1          0.232447      0.185958          352.913372                0.037707
# 2          0.280248      0.288369         3056.092148                0.658798
# 3          0.240964      0.225815          669.806992                0.109240
# 4          0.206280      0.204616          571.459726                0.151146
#
#   LoanApproved  RiskScore
# 0            0       50.0
# 1            1       44.8
# 2            0       57.0
# 3            1       32.8
# 4            1       47.2
#
# [5 rows x 36 columns]

# %%
df.shape
# Out:
# (100000, 36)

# %%
def clean_dataset(dataset, features_to_remove):
    dataset = dataset.drop(columns=features_to_remove)
    dataset = dataset.dropna()
    dataset['EducationLevel'] = dataset['EducationLevel'].astype('category').cat.codes
    dataset['EmploymentStatus'] = dataset['EmploymentStatus'].astype('category').cat.codes
    dataset['HomeOwnershipStatus'] = dataset['HomeOwnershipStatus'].astype('category').cat.codes
    return dataset

# %%
columns_to_remove = ['ApplicationDate', 'LoanPurpose', 'MaritalStatus', 'LoanApproved']
df = clean_dataset(df, columns_to_remove)
df
# Out:
#        Age  AnnualIncome  CreditScore  EmploymentStatus  EducationLevel  \
# 0       61         40100          607                 0               3
# 1       45        196328          662                 0               4
# 2       41         69929          500                 0               4
# 3       18        178352          576                 0               2
# 4       36         69982          588                 1               0
# ...    ...           ...          ...               ...             ...
# 99995   43         35498          457                 0               3
# 99996   46         61922          508                 0               3
# 99997   44        124415          596                 0               1
# 99998   51         41873          623                 0               0
# 99999   36         54503          532                 0               3
#
#        Experience  LoanAmount  LoanDuration  NumberOfDependents  \
# 0              39       15442            24                   3
# 1              21       18447           108                   0
# 2              14       55248            24                   2
# 3               0       23964            60                   0
# 4               9       15280            36                   3
# ...           ...         ...           ...                 ...
# 99995          22       22207            48                   1
# 99996          21       10362            96                   0
# 99997          23       12101            48                   2
# 99998          31       19587            36                   1
# 99999          18       37184            72                   4
#
#        HomeOwnershipStatus  ...  TotalLiabilities  MonthlyIncome  \
# 0                        1  ...             17841    3341.666667
# 1                        0  ...             28617   16360.666667
# 2                        0  ...             41550    5827.416667
# 3                        0  ...             95768    7870.833333
# 4                        3  ...             29677    5831.833333
# ...                    ...  ...               ...            ...
# 99995                    0  ...            104602    2958.166667
# 99996                    0  ...              7607    5160.166667
# 99997                    2  ...             61567   10367.916667
# 99998                    3  ...             10506    3489.416667
# 99999                    3  ...             81621    4541.916667
#
#        UtilityBillsPaymentHistory  JobTenure  NetWorth  BaseInterestRate  \
# 0                        0.895582          7      3561          0.186942
# 1                        0.828974          8      8735          0.232447
# 2                        0.883624          6      6961          0.280248
# 3                        0.923136          4    580260          0.240964
# 4                        0.847818          6     70933          0.206280
# ...                           ...        ...       ...               ...
# 99995                    0.964905          4     94710          0.288707
# 99996                    0.884803          7     81172          0.291362
# 99997                    0.782392          5      6594          0.209101
# 99998                    0.714821          7     42662          0.193087
# 99999                    0.753001          5     10397          0.286184
#
#        InterestRate  MonthlyLoanPayment  TotalDebtToIncomeRatio  RiskScore
# 0          0.214766          797.117108                0.375895       50.0
# 1          0.185958          352.913372                0.037707       44.8
# 2          0.288369         3056.092148                0.658798       57.0
# 3          0.225815          669.806992                0.109240       32.8
# 4          0.204616          571.459726                0.151146       47.2
# ...             ...                 ...                     ...        ...
# 99995      0.315079          819.178548                0.428028       54.0
# 99996      0.289410          278.132832                0.131223       56.0
# 99997      0.250921          401.856400                0.096245       40.8
# 99998      0.182292          710.371293                0.316778       50.0
# 99999      0.282165         1076.250956                0.348146       52.0
#
# [100000 rows x 32 columns]

# %%
X = df.drop(columns=['RiskScore'], axis=1)
y = df['RiskScore']

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# # Otimizando o modelo

# %%
xgboost_model = XGBRegressor()

# %%
# número de folds
k = 5
mape_scores = []
kf = KFold(n_splits=k, shuffle=True, random_state=42)

for train_index, val_index in kf.split(X):
  x_train, x_val = X[train_index], X[val_index]
  y_train, y_val = y[train_index], y[val_index]

  xgboost_model.fit(x_train, y_train)
  y_pred = xgboost_model.predict(x_val)

  mape = mean_absolute_percentage_error(y_val, y_pred)
  mape_scores.append(mape)

# %%
mape_scores
# Out:
# [0.029783314730107417,
#  0.030529115814823524,
#  0.030803860765414096,
#  0.030527437453361454,
#  0.030294396830117528]

# %% [markdown]
# Os valores estão muito próximos para cada fold, o que é um bom sinal. Vamos calcular a média:

# %%
mape_mean = np.mean(mape_scores)
print(f'MAPE médio: {mape_mean}')
# Out:
# MAPE médio: 0.030387625118764805

# %% [markdown]
# ### Separando 10% para o teste final

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
xgboost_model = XGBRegressor()

# %%
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)
mape_scores = []

for train_index, val_index in kf.split(X_train, y_train):
  x_train, x_val = X[train_index], X[val_index]
  y_train, y_val = y[train_index], y[val_index]

  xgboost_model.fit(x_train, y_train)
  y_pred = xgboost_model.predict(x_val)

  mape = mean_absolute_percentage_error(y_val, y_pred)
  mape_scores.append(mape)

# %%
print(mape_scores)
mape_mean = np.mean(mape_scores)
print(f'MAPE médio: {mape_mean}')
# Out:
# [0.030723913846194047, 0.03057872799735719, 0.03100711062851216, 0.030425204561300517, 0.030340627784394662]
# MAPE médio: 0.030615116963551715

# %%
y_pred_2 = xgboost_model.predict(X_test)

# %%
mape_test = mean_absolute_percentage_error(y_test, y_pred_2)
mape_test
# Out:
# 0.025054074384214507

# %%
def evaluate_real_data(model):
  df_test = pd.read_csv(test_dataset)
  df_test = clean_dataset(df_test, columns_to_remove)
  X = df_test.drop(columns=['RiskScore'])
  y = df_test['RiskScore']

  X = scaler.transform(X)

  _, X_test, _, y_test = train_test_split(X, y, test_size=0.9, random_state=42)
  y_pred = xgboost_model.predict(X_test)

  mse = mean_squared_error(y_test, y_pred, squared=True)
  rmse = np.sqrt(mse)
  mae = mean_absolute_error(y_test, y_pred)
  mape = mean_absolute_percentage_error(y_test, y_pred)
  r2 = r2_score(y_test, y_pred)
  print(f'MSE: {mse}\nRMSE: {rmse}\nMAE: {mae}\nMAPE: {mape}\nR2 Score: {r2}')

# %%
evaluate_real_data(xgboost_model)
# Out:
# MSE: 4.883951054623298
# RMSE: 2.2099663016940547
# MAE: 1.3907879536240189
# MAPE: 0.029663829557368064
# R2 Score: 0.9178399889708132
# /opt/homebrew/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# # Ajuste de hiperparâmetros

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.1, 0.01, 0.001],
    'subsample': [0.5, 0.7, 1]
}

# %%
# Create the XGBoost model object
xgboost = XGBRegressor()

# %%
# Create the GridSearchCV object
grid_search = GridSearchCV(xgboost, param_grid)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bin=None,
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'learning_rate': [0.1, 0.01, 0.001],
#                          'max_depth': [3, 5, 7], 'subsample': [0.5, 0.7, 1]})

# %%
df_results = pd.DataFrame(grid_search.cv_results_)
df_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.160108      0.008334         0.002872        0.000273
# 1        0.188361      0.021718         0.003103        0.000306
# 2        0.146910      0.004803         0.002731        0.000289
# 3        0.229782      0.007950         0.003960        0.000248
# 4        0.233514      0.005438         0.003825        0.000309
# 5        0.220560      0.002652         0.004002        0.000350
# 6        0.410430      0.029995         0.005363        0.000280
# 7        0.388246      0.010018         0.005795        0.000276
# 8        0.422529      0.024613         0.005356        0.000233
# 9        0.171753      0.011110         0.002532        0.000402
# 10       0.168089      0.009993         0.002750        0.000337
# 11       0.172284      0.007119         0.002684        0.000257
# 12       0.272462      0.015856         0.003965        0.000231
# 13       0.278777      0.013425         0.003954        0.000258
# 14       0.263994      0.009717         0.003741        0.000313
# 15       0.440930      0.013183         0.005592        0.000267
# 16       0.453671      0.012376         0.005551        0.000386
# 17       0.431280      0.011332         0.005385        0.000275
# 18       0.184064      0.005096         0.002803        0.000271
# 19       0.175871      0.003858         0.002691        0.000213
# 20       0.159060      0.004578         0.002746        0.000383
# 21       0.265191      0.009774         0.004033        0.000497
# 22       0.259151      0.009134         0.003789        0.000288
# 23       0.274247      0.032367         0.004067        0.000201
# 24       0.459241      0.011951         0.005456        0.000371
# 25       0.445574      0.011147         0.005787        0.000260
# 26       0.433517      0.005528         0.005479        0.000344
#
#    param_learning_rate param_max_depth param_subsample  \
# 0                  0.1               3             0.5
# 1                  0.1               3             0.7
# 2                  0.1               3               1
# 3                  0.1               5             0.5
# 4                  0.1               5             0.7
# 5                  0.1               5               1
# 6                  0.1               7             0.5
# 7                  0.1               7             0.7
# 8                  0.1               7               1
# 9                 0.01               3             0.5
# 10                0.01               3             0.7
# 11                0.01               3               1
# 12                0.01               5             0.5
# 13                0.01               5             0.7
# 14                0.01               5               1
# 15                0.01               7             0.5
# 16                0.01               7             0.7
# 17                0.01               7               1
# 18               0.001               3             0.5
# 19               0.001               3             0.7
# 20               0.001               3               1
# 21               0.001               5             0.5
# 22               0.001               5             0.7
# 23               0.001               5               1
# 24               0.001               7             0.5
# 25               0.001               7             0.7
# 26               0.001               7               1
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'subsam...           0.888224
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'subsam...           0.887929
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'subsam...           0.887731
# 3   {'learning_rate': 0.1, 'max_depth': 5, 'subsam...           0.910807
# 4   {'learning_rate': 0.1, 'max_depth': 5, 'subsam...           0.909619
# 5   {'learning_rate': 0.1, 'max_depth': 5, 'subsam...           0.909857
# 6   {'learning_rate': 0.1, 'max_depth': 7, 'subsam...           0.918714
# 7   {'learning_rate': 0.1, 'max_depth': 7, 'subsam...           0.918730
# 8   {'learning_rate': 0.1, 'max_depth': 7, 'subsam...           0.917836
# 9   {'learning_rate': 0.01, 'max_depth': 3, 'subsa...           0.470845
# 10  {'learning_rate': 0.01, 'max_depth': 3, 'subsa...           0.470011
# 11  {'learning_rate': 0.01, 'max_depth': 3, 'subsa...           0.469120
# 12  {'learning_rate': 0.01, 'max_depth': 5, 'subsa...           0.600846
# 13  {'learning_rate': 0.01, 'max_depth': 5, 'subsa...           0.600426
# 14  {'learning_rate': 0.01, 'max_depth': 5, 'subsa...           0.599473
# 15  {'learning_rate': 0.01, 'max_depth': 7, 'subsa...           0.678002
# 16  {'learning_rate': 0.01, 'max_depth': 7, 'subsa...           0.678036
# 17  {'learning_rate': 0.01, 'max_depth': 7, 'subsa...           0.677938
# 18  {'learning_rate': 0.001, 'max_depth': 3, 'subs...           0.080520
# 19  {'learning_rate': 0.001, 'max_depth': 3, 'subs...           0.080505
# 20  {'learning_rate': 0.001, 'max_depth': 3, 'subs...           0.080458
# 21  {'learning_rate': 0.001, 'max_depth': 5, 'subs...           0.109723
# 22  {'learning_rate': 0.001, 'max_depth': 5, 'subs...           0.109730
# 23  {'learning_rate': 0.001, 'max_depth': 5, 'subs...           0.109718
# 24  {'learning_rate': 0.001, 'max_depth': 7, 'subs...           0.129687
# 25  {'learning_rate': 0.001, 'max_depth': 7, 'subs...           0.129899
# 26  {'learning_rate': 0.001, 'max_depth': 7, 'subs...           0.129929
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.884006           0.884161           0.889264
# 1            0.884122           0.882055           0.889146
# 2            0.883178           0.883282           0.887513
# 3            0.906254           0.906458           0.911531
# 4            0.905396           0.906814           0.910654
# 5            0.905064           0.904813           0.910581
# 6            0.914188           0.915560           0.918931
# 7            0.914430           0.917114           0.919670
# 8            0.914661           0.914811           0.919955
# 9            0.470607           0.463832           0.469873
# 10           0.469592           0.463239           0.469388
# 11           0.468758           0.461908           0.468250
# 12           0.600319           0.593309           0.599987
# 13           0.599625           0.592402           0.599096
# 14           0.598601           0.591863           0.598042
# 15           0.676476           0.671766           0.675844
# 16           0.675886           0.671349           0.675477
# 17           0.675221           0.670691           0.674766
# 18           0.079970           0.077983           0.078811
# 19           0.079931           0.077928           0.078821
# 20           0.079849           0.077819           0.078800
# 21           0.109750           0.107634           0.108673
# 22           0.109695           0.107542           0.108658
# 23           0.109557           0.107532           0.108593
# 24           0.129239           0.127958           0.128531
# 25           0.129314           0.128081           0.128489
# 26           0.129224           0.128305           0.128336
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.886034         0.886338        0.002116                7
# 1            0.886055         0.885861        0.002554                8
# 2            0.884344         0.885209        0.002013                9
# 3            0.909783         0.908967        0.002203                4
# 4            0.908835         0.908263        0.001908                5
# 5            0.908367         0.907736        0.002395                6
# 6            0.917637         0.917006        0.001847                2
# 7            0.918170         0.917623        0.001798                1
# 8            0.916910         0.916834        0.001978                3
# 9            0.463457         0.467723        0.003348               16
# 10           0.462858         0.467018        0.003249               17
# 11           0.462215         0.466050        0.003270               18
# 12           0.596123         0.598117        0.002929               13
# 13           0.594987         0.597307        0.003090               14
# 14           0.593970         0.596390        0.002949               15
# 15           0.674441         0.675306        0.002107               10
# 16           0.674092         0.674968        0.002208               11
# 17           0.673279         0.674379        0.002380               12
# 18           0.078740         0.079205        0.000914               25
# 19           0.078649         0.079167        0.000927               26
# 20           0.078541         0.079093        0.000943               27
# 21           0.108697         0.108896        0.000787               22
# 22           0.108593         0.108844        0.000813               23
# 23           0.108522         0.108784        0.000793               24
# 24           0.128364         0.128756        0.000623               21
# 25           0.128473         0.128851        0.000660               19
# 26           0.128319         0.128823        0.000654               20

# %%
df_results.query('rank_test_score == 1')['params']
# Out:
# 7    {'learning_rate': 0.1, 'max_depth': 7, 'subsam...
# Name: params, dtype: object
